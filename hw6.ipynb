# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw6.ipynb")

# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 6: Clustering
# ### Associated lectures: [Lectures 14 and 15](https://ubc-cs.github.io/cpsc330-2025W2/#lecture-schedule-tentative)
#
# **Due date: See [deliverable due dates](https://ubc-cs.github.io/cpsc330-2025W2/#deliverable-due-dates-tentative)**.

# %% [markdown]
# ## Imports <a name="im"></a>

# %%
import os
from hashlib import sha1

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import nltk
import wikipedia
import string
import umap

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans, DBSCAN
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestNeighbors
from nltk.tokenize import sent_tokenize, word_tokenize
from sentence_transformers import SentenceTransformer
from wordcloud import WordCloud, STOPWORDS
from yellowbrick.cluster import KElbowVisualizer

# %matplotlib inline
pd.set_option("display.max_colwidth", 0)

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ## Instructions
# rubric={points}
#
# You will earn points for following these instructions and successfully submitting your work on Gradescope.
#
# ### Group wotk instructions
#
# **You may work with a partner on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
#
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
# - If you would like to use late tokens for the homework, all group members must have the necessary late tokens available. Please note that the late tokens will be counted for all members of the group.
#
#
# ### General submission instructions
#
# - Please **read carefully
# [Use of Generative AI policy](https://ubc-cs.github.io/cpsc330-2025W2/syllabus#use-of-generative-ai-in-the-course)** before starting the homework assignment.
# - **Run all cells before submitting:** Go to `Kernel -> Restart Kernel and Clear All Outputs`, then select `Run -> Run All Cells`. This ensures your notebook runs cleanly from start to finish without errors.
#
# - **Submit your files on Gradescope.**
#    - Upload only your `.ipynb` file **with outputs displayed** and any required output files.
#
#    - Do **not** submit other files from your repository.
#    - If you need help, see the [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/).
# - **Check that outputs render properly.**
#    - Make sure all plots and outputs appear in your submission.
#
#    - If your `.ipynb` file is too large and doesn't render on Gradescope, also upload a PDF version so the TAs can view your work.
# - **Keep execution order clean.**
#    - Execution numbers must start at "1" and increase in order.
#
#    - Notebooks without visible outputs may not be graded.
#    - Out-of-order or missing execution numbers may result in mark deductions.
# - **Follow course submission guidelines:** Review the [CPSC 330 homework instructions](https://ubc-cs.github.io/cpsc330-2025W2/docs/homework-instructions) for detailed guidance on completing and submitting assignments.
#
# </div>
#
# _Points:_ 4

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Document clustering warm-up
# <hr>
#
# In this homework, we will explore a popular application of clustering called [**document clustering**](https://en.wikipedia.org/wiki/Document_clustering). A large amount of unlabeled text data is available out there (e.g., news, recipes, online Q&A, tweets), and clustering is a commonly used technique to organize this data in a meaningful way.
#
# As a warm up, in this exercise you will cluster sentences from a toy corpus. Later in the homework you will work with a real corpus.
#
# The code below extracts introductory sentences of Wikipedia articles on a set of queries. To run the code successfully, you will need the `wikipedia` package installed in the course environment.
#
# ```
# conda activate cpsc330
# conda install -c conda-forge wikipedia
# ```
#
#
# **Your tasks:**
#
# Run the code below which
# - extracts content of Wikipedia articles on a set of queries
# - tokenizes the text (i.e., separates sentences) and
# - stores the 2nd sentence in each article as a document representing that article
#
# > Feel free to experiment with Wikipedia queries of your choice. But stick to the provided list for the final submission so that it's easier for the TAs to grade your submission.
#
# > For tokenization we are using the `nltk` package. If you do not have this package in the course environment, you will have to install it.
#
# ```
# conda activate cpsc330
# conda install -c anaconda nltk
# ```
#
# Even if you have the package installed via the course `conda` environment, you might have to download `nltk` pre-trained models, which can be done with the code below.

# %%
nltk.download("punkt")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\samin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\samin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
queries = [
    "Artificial Intelligence",
    "Deep learning",
    "Unsupervised learning",
    "Quantum Computer",
    "Environmental protection",
    "Climate Change",
    "Renewable Energy",
    "Biodiversity",
    "French Cuisine",
    "Bread food",
    "Dumpling food",
]
wiki_dict = {"wiki query": [], "text": [], "n_words": []}
remove_tokens = list(string.punctuation) + ['``', '’', '`', 'br', '"', "”", "''", "'s", "(", ")", "[", "]"]

# Running this code might take some time.
for query in queries:
    try:
        # Attempt to fetch the page content
        page_content = wikipedia.page(query).content
    except wikipedia.exceptions.PageError:
        print(f"Page not found for query: {query}. Skipping...")
        continue
    except wikipedia.exceptions.DisambiguationError as e:
        print(f"Query: {query} led to a disambiguation page. Choosing the first option: {e.options[0]}")
        page_content = wikipedia.page(e.options[0]).content

    text = sent_tokenize(page_content)[0]
    tokenized = word_tokenize(text)
    text_pp = [token.lower() for token in tokenized if token.lower() not in remove_tokens]
    wiki_dict["n_words"].append(len(text_pp))
    wiki_dict["text"].append(" ".join(text_pp))
    wiki_dict["wiki query"].append(query)

wiki_df = pd.DataFrame(wiki_dict)
wiki_df
# Out:
#                   wiki query  \
# 0   Artificial Intelligence
# 1   Deep learning
# 2   Unsupervised learning
# 3   Quantum Computer
# 4   Environmental protection
# 5   Climate Change
# 6   Renewable Energy
# 7   Biodiversity
# 8   French Cuisine
# 9   Bread food
# 10  Dumpling food
#
#                                                                                                                                                                                                              text  \
# 0   artificial intelligence ai is the capability of computational systems to perform tasks typically associated with human intelligence such as learning reasoning problem-solving perception and decision-making
# 1   in machine learning deep learning dl focuses on utilizing multilayered neural networks to perform tasks such as classification regression and representation learning
# 2   in machine learning supervised learning sl is a type of machine learning paradigm where an algorithm learns to map input data to a specific output based on example input-output pairs
# 3   a quantum computer is a real or theoretical computer that exploits superposed and entangled states
# 4   environmental protection or environment protection refers to the taking of measures to protecting the natural environment prevent pollution and maintain ecological balance
# 5   present-day climate change includes both global warming — the ongoing increase in global average temperature — and its wider effects on earth climate system
# 6   renewable energy also called green energy is energy made from renewable natural resources that are replenished on a human timescale
# 7   biologists most often define biodiversity as the totality of genes species and ecosystems of a region
# 8   french cuisine is the cooking traditions and practices of france
# 9   bread is a baked food product made from water flour and often yeast
# 10  manti is a type of dumpling mainly found in turkish cuisine armenian cuisine and central asian cuisine but also in west asia south caucasus and the balkans
#
#     n_words
# 0   25
# 1   22
# 2   30
# 3   15
# 4   22
# 5   24
# 6   20
# 7   16
# 8   10
# 9   13
# 10  27

# %% [markdown]
# Our toy corpus has six toy documents (`text` column in the dataframe) extracted from Wikipedia queries.

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.1 How many clusters?
# rubric={reasoning}
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# - If tasked with manually clustering documents from this toy corpus, how many clusters would you identify, and what labels would you assign to each cluster?
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.1
#
# </div>
#
# _Points:_ 1

# %% [markdown]
# I would identify 3 clusters with these labels:
#
# 1. AI/ML & computing - Artificial Intelligence, Deep learning, Unsupervised learning, Quantum Computer
#
#
# 1. Environment & sustainability - Environmental protection, Climate Change, Renewable Energy, Biodiversity
#
# 1. Food & cuisine - French Cuisine, Bread food, Dumpling food

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.2 K-Means with bag-of-words representation
# rubric={accuracy}
#
# In the lecture, we explored how **data representation significantly impacts clustering quality**. We saw that replacing a **flattened image representation** with feature vectors extracted from **pre-trained models** greatly improved clustering results.
#
# What about text data? In previous machine learning courses, we have used the **bag-of-words (BoW) representation** to numerically encode text, where each document is represented with a vector of word frequencies.
#
# In this exercise, you will **cluster documents** using this **simplistic text representation**.
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# 1. Use [`CountVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) with its **default settings** to transform the `text` column in `wiki_df` into a numerical representation.
#
# 2. Use [`KMeans`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) to cluster the encoded documents and store the cluster labels in `kmeans_bow_labels`.
#    - Set `random_state=42` for **reproducibility**.
#
#    - Use the **number of clusters** (`n_clusters`) identified in the **previous exercise**.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.2
#
# </div>
#
# _Points:_ 2

# %%
vec = CountVectorizer()
X_bow = vec.fit_transform(wiki_df["text"])

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_bow_labels = kmeans.fit_predict(X_bow)

# %%
wiki_df["bow_kmeans"] = kmeans_bow_labels
wiki_df
# Out:
#                   wiki query  \
# 0   Artificial Intelligence
# 1   Deep learning
# 2   Unsupervised learning
# 3   Quantum Computer
# 4   Environmental protection
# 5   Climate Change
# 6   Renewable Energy
# 7   Biodiversity
# 8   French Cuisine
# 9   Bread food
# 10  Dumpling food
#
#                                                                                                                                                                                                              text  \
# 0   artificial intelligence ai is the capability of computational systems to perform tasks typically associated with human intelligence such as learning reasoning problem-solving perception and decision-making
# 1   in machine learning deep learning dl focuses on utilizing multilayered neural networks to perform tasks such as classification regression and representation learning
# 2   in machine learning supervised learning sl is a type of machine learning paradigm where an algorithm learns to map input data to a specific output based on example input-output pairs
# 3   a quantum computer is a real or theoretical computer that exploits superposed and entangled states
# 4   environmental protection or environment protection refers to the taking of measures to protecting the natural environment prevent pollution and maintain ecological balance
# 5   present-day climate change includes both global warming — the ongoing increase in global average temperature — and its wider effects on earth climate system
# 6   renewable energy also called green energy is energy made from renewable natural resources that are replenished on a human timescale
# 7   biologists most often define biodiversity as the totality of genes species and ecosystems of a region
# 8   french cuisine is the cooking traditions and practices of france
# 9   bread is a baked food product made from water flour and often yeast
# 10  manti is a type of dumpling mainly found in turkish cuisine armenian cuisine and central asian cuisine but also in west asia south caucasus and the balkans
#
#     n_words  bow_kmeans
# 0   25       1
# 1   22       2
# 2   30       2
# 3   15       1
# 4   22       0
# 5   24       1
# 6   20       1
# 7   16       1
# 8   10       1
# 9   13       1
# 10  27       1

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.3 K-Means with sentence embedding representation
# rubric={accuracy}
#
# In the previous exercise, you may have noticed that clustering results were suboptimal. While the bag-of-words (BoW) representation is useful, it has significant limitations. It does not capture word order or context effectively.
#
# To improve text representation, we can use pre-trained models, similar to those used for image data, to extract richer, context-aware embeddings through transfer learning. In this lab, we will use the **pre-trained model** `'all-MiniLM-L6-v2'`, available via the [Sentence Transformers](https://www.sbert.net/index.html) package.
#
# This deep learning model generates **dense, fixed-length vector representations** of sentences, capturing **semantic meaning and contextual information**. These representations are particularly effective for **clustering and semantic similarity tasks**. If you're interested in exploring more **pre-trained models**, refer to the [full list here](https://www.sbert.net/docs/pretrained_models.html). We will explore these representations further in **DSCI 575**.
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# 1. Run the code below to create sentence embedding representation of documents in our toy corpus.
#
# 3. Apply `KMeans` to the **sentence embeddings** (`emb_sents`) and store the cluster labels in `kmeans_emb_labels`. Use the following parameters:
#     - `random_state=42` (for reproducibility)
#
#     - `n_clusters`=the number of clusters you identified in 1.1
#
# Note
# - The code below might throw a warning. You may ignore it for the purpose of this lab.
# </div>

# %%
embedder = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
emb_sents = embedder.encode(wiki_df["text"].tolist())
emb_sent_df = pd.DataFrame(emb_sents, index=wiki_df.index)
emb_sent_df
# Out:
#            0         1         2         3         4         5         6  \
# 0  -0.005857 -0.004795 -0.000976  0.011121  0.005294 -0.061630  0.062072
# 1  -0.122905 -0.092450  0.085379 -0.009761  0.001422  0.069146 -0.046654
# 2  -0.056721 -0.049697 -0.014780  0.022572  0.051773  0.007456  0.008632
# 3  -0.071932 -0.006760 -0.083421  0.022650 -0.116415  0.034988 -0.055792
# 4  -0.012700  0.101830  0.066676 -0.007987  0.140040  0.041627  0.035495
# 5  -0.014444  0.022869  0.145982  0.054865  0.085204 -0.014689 -0.102757
# 6  -0.044869  0.076882 -0.012749  0.033335  0.067894 -0.002327  0.031620
# 7   0.027811  0.042017 -0.034509 -0.029904  0.008833  0.021378 -0.063310
# 8   0.026616 -0.019929 -0.008049 -0.025907 -0.055372  0.011235 -0.024538
# 9  -0.014786  0.055887 -0.020880  0.005313 -0.025037  0.040478  0.035260
# 10 -0.017367  0.046664 -0.089176  0.010790 -0.084132 -0.039986  0.033869
#
#            7         8         9  ...       374       375       376       377  \
# 0   0.033673 -0.035251  0.074072  ...  0.088312 -0.006600  0.036511 -0.020797
# 1  -0.069960 -0.021858 -0.052803  ...  0.065826  0.031800 -0.021052 -0.113772
# 2  -0.074847 -0.065573 -0.027284  ...  0.014761 -0.022392  0.021360 -0.107016
# 3  -0.045055 -0.017993  0.020915  ... -0.076031 -0.016973 -0.054588 -0.020448
# 4  -0.050723 -0.037633  0.055886  ... -0.042105 -0.038883  0.018268  0.009920
# 5   0.016853 -0.023799  0.021148  ...  0.011778  0.016817 -0.020041  0.006375
# 6  -0.021576  0.046619  0.005089  ... -0.021575 -0.017596 -0.069995  0.004461
# 7   0.014000  0.069925  0.000224  ... -0.018486 -0.022946 -0.000922 -0.030791
# 8  -0.065724  0.058374 -0.062895  ... -0.059513  0.077446 -0.059827 -0.021454
# 9   0.024938  0.017546  0.072433  ... -0.082098  0.037856 -0.020007 -0.087252
# 10 -0.100715 -0.010708 -0.068042  ...  0.020180  0.021404  0.010321 -0.017518
#
#          378       379       380       381       382       383
# 0  -0.002082  0.058263  0.061881  0.097383  0.058155 -0.052016
# 1  -0.013588  0.056793 -0.013167  0.009044 -0.011912 -0.011387
# 2   0.020530  0.045678  0.052755  0.005429  0.022018 -0.010994
# 3  -0.016833  0.120573  0.027863  0.076044  0.060111  0.057609
# 4   0.028208  0.052759 -0.009605 -0.004518  0.060853  0.057709
# 5   0.055428  0.076868 -0.047152 -0.114797 -0.056382  0.022349
# 6  -0.040409 -0.043067  0.044042 -0.050977  0.056506  0.048708
# 7  -0.040390  0.041277  0.003378  0.018937  0.029736 -0.083945
# 8   0.088102 -0.127180 -0.031399  0.120572  0.072373 -0.058336
# 9   0.058163 -0.044187 -0.030253 -0.080385  0.075614 -0.070403
# 10  0.079356 -0.034642 -0.022086 -0.018417 -0.012915  0.004780
#
# [11 rows x 384 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.3
#
# </div>
#
# _Points:_ 2

# %%
kmeans_emb = KMeans(n_clusters=3, random_state=42)
kmeans_emb_labels = kmeans_emb.fit_predict(emb_sents)

# %%
wiki_df["emb_kmeans"] = kmeans_emb_labels
wiki_df
# Out:
#                   wiki query  \
# 0   Artificial Intelligence
# 1   Deep learning
# 2   Unsupervised learning
# 3   Quantum Computer
# 4   Environmental protection
# 5   Climate Change
# 6   Renewable Energy
# 7   Biodiversity
# 8   French Cuisine
# 9   Bread food
# 10  Dumpling food
#
#                                                                                                                                                                                                              text  \
# 0   artificial intelligence ai is the capability of computational systems to perform tasks typically associated with human intelligence such as learning reasoning problem-solving perception and decision-making
# 1   in machine learning deep learning dl focuses on utilizing multilayered neural networks to perform tasks such as classification regression and representation learning
# 2   in machine learning supervised learning sl is a type of machine learning paradigm where an algorithm learns to map input data to a specific output based on example input-output pairs
# 3   a quantum computer is a real or theoretical computer that exploits superposed and entangled states
# 4   environmental protection or environment protection refers to the taking of measures to protecting the natural environment prevent pollution and maintain ecological balance
# 5   present-day climate change includes both global warming — the ongoing increase in global average temperature — and its wider effects on earth climate system
# 6   renewable energy also called green energy is energy made from renewable natural resources that are replenished on a human timescale
# 7   biologists most often define biodiversity as the totality of genes species and ecosystems of a region
# 8   french cuisine is the cooking traditions and practices of france
# 9   bread is a baked food product made from water flour and often yeast
# 10  manti is a type of dumpling mainly found in turkish cuisine armenian cuisine and central asian cuisine but also in west asia south caucasus and the balkans
#
#     n_words  bow_kmeans  emb_kmeans
# 0   25       1           2
# 1   22       2           2
# 2   30       2           2
# 3   15       1           2
# 4   22       0           0
# 5   24       1           0
# 6   20       1           0
# 7   16       1           0
# 8   10       1           1
# 9   13       1           1
# 10  27       1           1

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.4 DBSCAN with sentence embedding representation and cosine distance
# rubric={accuracy}
#
# Now, let's apply [`DBSCAN`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html) to our toy dataset.
#
# Unlike K-Means, which relies on Euclidean distance due to its use of centroids, DBSCAN allows us to experiment with different distance metrics. For text data, [**cosine similarity**](https://scikit-learn.org/stable/modules/metrics.html#cosine-similarity) (or its complement, **cosine distance**) is often more effective than Euclidean distance.
#
# The **cosine distance** between two vectors $u$ and $v$ is defined as:
#
# $$distance_{cosine}(u,v) = 1 - (\frac{u \cdot v}{\left\lVert u\right\rVert_2 \left\lVert v\right\rVert_2})$$
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# - Apply **DBSCAN** to cluster documents encoded with **sentence embeddings** (`emb_sents`) and store the cluster labels in `dbscan_emb_labels`.
#
# - Set `metric='cosine'` to use **cosine distance** for clustering.
# - Tune the **hyperparameters** `eps` and `min_samples` to obtain meaningful clusters, as the default values are unlikely to work well on this dataset.
#
# **Notes for tuning the hyperparameters:**
#
# - Start by examining the minimum, maximum, and mean cosine distances in the dataset. You can compute pairwise cosine distances using the package imported below.
#
# - Experiment with a range of `eps` values and print the number of clusters and their sizes for each value.
# - Select the `eps` value that produces the desired number of clusters.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.4
#
# </div>
#
# _Points:_ 4

# %%
dist = cosine_distances(emb_sents)
upper_tri = np.triu_indices_from(dist, k=1)
pairwise_dists = dist[upper_tri]
print("Min cosine distance:", pairwise_dists.min())
print("Max cosine distance:", pairwise_dists.max())
print("Mean cosine distance:", pairwise_dists.mean())
# Out:
# Min cosine distance: 0.51783955
# Max cosine distance: 1.0320184
# Mean cosine distance: 0.89676905

# %%
for eps in [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
    dbscan = DBSCAN(eps=eps, min_samples=3, metric='cosine')
    labels = dbscan.fit_predict(emb_sents)
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise = list(labels).count(-1)
    unique, counts = np.unique(labels, return_counts=True)
    print(f"eps={eps}: n_clusters={n_clusters}, n_noise={n_noise}, sizes={dict(zip(unique, counts))}")
# Out:
# eps=0.3: n_clusters=0, n_noise=11, sizes={np.int64(-1): np.int64(11)}
# eps=0.4: n_clusters=0, n_noise=11, sizes={np.int64(-1): np.int64(11)}
# eps=0.5: n_clusters=0, n_noise=11, sizes={np.int64(-1): np.int64(11)}
# eps=0.6: n_clusters=1, n_noise=8, sizes={np.int64(-1): np.int64(8), np.int64(0): np.int64(3)}
# eps=0.7: n_clusters=2, n_noise=4, sizes={np.int64(-1): np.int64(4), np.int64(0): np.int64(4), np.int64(1): np.int64(3)}
# eps=0.8: n_clusters=3, n_noise=0, sizes={np.int64(0): np.int64(4), np.int64(1): np.int64(4), np.int64(2): np.int64(3)}
# eps=0.9: n_clusters=1, n_noise=0, sizes={np.int64(0): np.int64(11)}

# %%
dbscan_emb = DBSCAN(eps=0.8, min_samples=3, metric='cosine')
dbscan_emb_labels = dbscan_emb.fit_predict(emb_sents)

# %%
wiki_df["emb_dbscan"] = dbscan_emb_labels
wiki_df
# Out:
#                   wiki query  \
# 0   Artificial Intelligence
# 1   Deep learning
# 2   Unsupervised learning
# 3   Quantum Computer
# 4   Environmental protection
# 5   Climate Change
# 6   Renewable Energy
# 7   Biodiversity
# 8   French Cuisine
# 9   Bread food
# 10  Dumpling food
#
#                                                                                                                                                                                                              text  \
# 0   artificial intelligence ai is the capability of computational systems to perform tasks typically associated with human intelligence such as learning reasoning problem-solving perception and decision-making
# 1   in machine learning deep learning dl focuses on utilizing multilayered neural networks to perform tasks such as classification regression and representation learning
# 2   in machine learning supervised learning sl is a type of machine learning paradigm where an algorithm learns to map input data to a specific output based on example input-output pairs
# 3   a quantum computer is a real or theoretical computer that exploits superposed and entangled states
# 4   environmental protection or environment protection refers to the taking of measures to protecting the natural environment prevent pollution and maintain ecological balance
# 5   present-day climate change includes both global warming — the ongoing increase in global average temperature — and its wider effects on earth climate system
# 6   renewable energy also called green energy is energy made from renewable natural resources that are replenished on a human timescale
# 7   biologists most often define biodiversity as the totality of genes species and ecosystems of a region
# 8   french cuisine is the cooking traditions and practices of france
# 9   bread is a baked food product made from water flour and often yeast
# 10  manti is a type of dumpling mainly found in turkish cuisine armenian cuisine and central asian cuisine but also in west asia south caucasus and the balkans
#
#     n_words  bow_kmeans  emb_kmeans  emb_dbscan
# 0   25       1           2           0
# 1   22       2           2           0
# 2   30       2           2           0
# 3   15       1           2           0
# 4   22       0           0           1
# 5   24       1           0           1
# 6   20       1           0           1
# 7   16       1           0           1
# 8   10       1           1           2
# 9   13       1           1           2
# 10  27       1           1           2

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.5 Hierarchical clustering with sentence embedding representation
# rubric={accuracy}
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# Apply hierarchical clustering on `emb_sents`. In particular
# 1. Create and show a dendrogram with `complete` linkage and `metric='cosine'` on this toy dataset.
#
# 3. Create flat clusters using `fcluster` with appropriate hyperparameters and store cluster labels to `hier_emb_labels` variable below.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.5
#
# </div>
#
# _Points:_ 3

# %%
Z = linkage(emb_sents, method='complete', metric='cosine')

plt.figure(figsize=(10, 6))
dendrogram(Z, labels=wiki_df["wiki query"].tolist(), leaf_rotation=90)
plt.xlabel("Sample (wiki query)")
plt.ylabel("Distance (cosine)")
plt.title("Hierarchical clustering (complete linkage, cosine)")
plt.tight_layout()
plt.show()

# %%
hier_emb_labels = fcluster(Z, t=3, criterion='maxclust')
hier_emb_labels = hier_emb_labels - 1

# %%
wiki_df["emb_hierarchical"] = hier_emb_labels
wiki_df
# Out:
#                   wiki query  \
# 0   Artificial Intelligence
# 1   Deep learning
# 2   Unsupervised learning
# 3   Quantum Computer
# 4   Environmental protection
# 5   Climate Change
# 6   Renewable Energy
# 7   Biodiversity
# 8   French Cuisine
# 9   Bread food
# 10  Dumpling food
#
#                                                                                                                                                                                                              text  \
# 0   artificial intelligence ai is the capability of computational systems to perform tasks typically associated with human intelligence such as learning reasoning problem-solving perception and decision-making
# 1   in machine learning deep learning dl focuses on utilizing multilayered neural networks to perform tasks such as classification regression and representation learning
# 2   in machine learning supervised learning sl is a type of machine learning paradigm where an algorithm learns to map input data to a specific output based on example input-output pairs
# 3   a quantum computer is a real or theoretical computer that exploits superposed and entangled states
# 4   environmental protection or environment protection refers to the taking of measures to protecting the natural environment prevent pollution and maintain ecological balance
# 5   present-day climate change includes both global warming — the ongoing increase in global average temperature — and its wider effects on earth climate system
# 6   renewable energy also called green energy is energy made from renewable natural resources that are replenished on a human timescale
# 7   biologists most often define biodiversity as the totality of genes species and ecosystems of a region
# 8   french cuisine is the cooking traditions and practices of france
# 9   bread is a baked food product made from water flour and often yeast
# 10  manti is a type of dumpling mainly found in turkish cuisine armenian cuisine and central asian cuisine but also in west asia south caucasus and the balkans
#
#     n_words  bow_kmeans  emb_kmeans  emb_dbscan  emb_hierarchical
# 0   25       1           2           0           1
# 1   22       2           2           0           1
# 2   30       2           2           0           1
# 3   15       1           2           0           1
# 4   22       0           0           1           2
# 5   24       1           0           1           2
# 6   20       1           0           1           2
# 7   16       1           0           1           2
# 8   10       1           1           2           0
# 9   13       1           1           2           0
# 10  27       1           1           2           0

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.6 Discussion
# rubric={reasoning}
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# Reflect on and discuss the clustering results of the methods you explored in the previous exercises, focusing on the following points:
# - effect of input representation on clustering results
#
# - whether the clustering results match with your intuitions and the challenges associated with getting the desired clustering results with each method
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.6
#
# </div>
#
# _Points:_ 4

# %% [markdown]
# - Bag-of-Words + K-means group by word overlap and not meaning, so it performs poorly when clustering.
# - The other 3 techniques (Embeddings + K-means / DBSCAN / Hierarchical Clustering) all result in the same clusters and matches how I clustered them.
# - So the main takeaway is that input representation has a big effect in clustering.
# - The embedding based models match intuition well if we properly set the hyperparameters. However, the hyperparameter tuning for DBSCAN was little extra work.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### 1.7 Visualizing clusters
# rubric={points:4}
#
#
# One approach to working with unlabeled data is visualization. That said, our data is high-dimensional, making it challenging to visualize. Take sentence embedding representation as an example: each instance is depicted in 768 dimensions. To visualize such high-dimensional data, we can employ dimensionality reduction techniques to extract the most significant 2 or 3 components, and then visualize this low-dimensional data.
#
# Given data as a `numpy` array and corresponding cluster assignments, the `plot_umap_clusters` function below transforms the data by applying dimensionality reduction technique called [UMAP](https://umap-learn.readthedocs.io/en/latest/) to it and plots the transformed data with different colours for different clusters.
#
# > *Note: At this point we are using this function only for visualization and you are not expected to understand the UMAP part.*
#
# You'll have to install the `umap-learn` package in the course conda environment either with `conda` or `pip`, as described in the [documentation](https://umap-learn.readthedocs.io/en/latest/index.html).
#
# ```
# > conda activate cpsc330
# > conda install -c conda-forge umap-learn
# ```
# or
#
# ```
# > conda activate cpsc330
# > pip install umap-learn
# ```
#
# If you get an error with the import below try
#
# ```
# pip install --upgrade numba umap-learn
# ```
#
# <div class="alert alert-info">
#
# **Your tasks:**
#
# 1. Visualize the clusters created by the methods above using `plot_umap_clusters` function below. In other words, visualize clusters identified by each of the methods below.
#     - K-Means with bag-of-words representation
#     - K-Means with sentence embedding representation
#     - DBSCAN with sentence embedding representation
#     - Flat cluster of hierarchical clustering with sentence embedding representation
# </div>

# %%
def plot_umap_clusters(
    data,
    cluster_labels,
    raw_texts=None,
    show_labels=False,
    point_size=50,
    n_neighbors=15,
    title="UMAP Visualization",
    ignore_noise=False,
):
    """
    Perform dimensionality reduction using UMAP and visualize the resulting clusters.

    Parameters
    ----------
    data : np.ndarray
        Feature matrix to be reduced.
    cluster_labels : array-like
        Cluster label for each data point.
    raw_texts : list of str, optional
        Original texts corresponding to the data points (used when show_labels=True).
    show_labels : bool, default=False
        Whether to annotate points with text labels.
    point_size : int, default=50
        Size of the scatterplot points.
    n_neighbors : int, default=15
        Number of neighbors used in UMAP.
    title : str, default="UMAP Visualization"
        Title of the plot.
    ignore_noise : bool, default=False
        Whether to exclude points labeled as noise (-1).

    Returns
    -------
    None
    """
    reducer = umap.UMAP(n_neighbors=n_neighbors, random_state=42)
    embedding = reducer.fit_transform(data)

    df = pd.DataFrame(embedding, columns=["dim1", "dim2"])
    df["cluster"] = cluster_labels

    if ignore_noise:
        df = df[df["cluster"] != -1]

    fig, ax = plt.subplots(figsize=(6, 5))
    ax.set_title(title)

    scatter = ax.scatter(
        df["dim1"], df["dim2"],
        c=df["cluster"], cmap="tab20b", s=point_size
    )

    ax.legend(*scatter.legend_elements(), title="Clusters", loc="best")

    if show_labels and raw_texts is not None:
        for (x, y, text) in zip(df["dim1"], df["dim2"], raw_texts):
            ax.annotate(" ".join(text.split()[:10]), (x, y), fontsize=8)

    plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1.7
#
# </div>
#
# _Points:_ 4

# %%
plot_umap_clusters(X_bow.toarray(), kmeans_bow_labels, title="K-Means (bag-of-words)")
plot_umap_clusters(emb_sents, kmeans_emb_labels, title="K-Means (embeddings)")
plot_umap_clusters(emb_sents, dbscan_emb_labels, title="DBSCAN (embeddings)")
plot_umap_clusters(emb_sents, hier_emb_labels, title="Hierarchical (embeddings)")
# Out:
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:2462: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:2462: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:2462: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\samin\miniconda3\envs\ml-conda\Lib\site-packages\umap\umap_.py:2462: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: [Food.com](https://www.food.com/) recipes
# <hr>
#
# Now that we have applied document clustering on a toy corpus, let's move to a more realistic corpus.
#
# In the lecture, we worked on an activity of manually clustering food items and discussed challenges associated with it. We also applied different clustering algorithms to cluster food images. We'll continue this theme of clustering food items in this lab. But instead of images we will cluster textual description of food items, i.e., recipe names.
#
# In this assignment, we will work with a sample of [Kaggle's Food.com recipes corpus](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions). This corpus contains 180K+ recipes and 700K+ recipe reviews. In this lab, we'll only focus on recipes and **not** on reviews. The recipes are present in `RAW_recipes.csv`. Our goal is to find categories or groupings of recipes from this corpus based on their names.
#
# **Your tasks:**
#
# - Download [`RAW_recipes.csv`](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions?select=RAW_recipes.csv) and put it under the `data` directory in the homework folder.
# - Run the code below. The dataset is quite large, and in this assignment, for speed, you will work with a sample of the dataset. The function `get_recipes_sample` below carries out some preliminary preprocessing and returns a sample of the recipes with most frequent tags.
#
# > *Note: Depending upon the capacity of your computer, feel free to increase or decrease the size of this sample by changing the value for `n_tags`. If you decide to go with a different value of `n_tags`, state it clearly in Exercise 2.1 so that the grader knows about it.*

# %%
orig_recipes_df = pd.read_csv("data/RAW_recipes.csv")
orig_recipes_df.shape
# Out:
# (231637, 12)

# %%
def get_recipes_sample(orig_recipes_df, n_tags=300, min_len=5):
    orig_recipes_df = orig_recipes_df.dropna()  # Remove rows with NaNs.
    orig_recipes_df = orig_recipes_df.drop_duplicates(
        "name"
    )  # Remove rows with duplicate names.
    # Remove rows where recipe names are too short (< 5 characters).
    orig_recipes_df = orig_recipes_df[orig_recipes_df["name"].apply(len) >= min_len]
    # Only consider the rows where tags are one of the most frequent n tags.
    first_n = orig_recipes_df["tags"].value_counts()[0:n_tags].index.tolist()
    recipes_df = orig_recipes_df[orig_recipes_df["tags"].isin(first_n)]
    return recipes_df

# %%
recipes_df = get_recipes_sample(orig_recipes_df)
recipes_df.shape
# Out:
# (9100, 12)

# %%
recipes_df["name"]
# Out:
# 42        i yam what i yam  muffins
# 101       to your health  muffins
# 129       250 00 chocolate chip cookies
# 138       lplermagronen
# 163       california roll   salad
#                    ...
# 231514    zucchini blueberry bread
# 231539    zucchini parmesan pancakes
# 231547    zucchini salsa burgers
# 231596    zuppa toscana
# 231629    zydeco salad
# Name: name, Length: 9100, dtype: str

# %% [markdown]
# <br><br>

# %% [markdown]
# **In the rest of the homework, we will use `recipes_df` above, which is a subset of the original dataset.** lame

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 2.1 Longest and shorter recipe names
# rubric={points:2}
#
# **Your tasks:**
#
# 1. Print the shortest and longest recipe names (length in terms of number of characters) from `recipes_df`. If there is more than one recipe with the same shortest/longest length, store **one** of them in `shortest_recipe` and/or `longest_recipe` as a **string**.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.1
#
# </div>
#
# _Points:_ 2

# %%
shortest_recipe = recipes_df.loc[recipes_df["name"].str.len().idxmin(), "name"]
longest_recipe = recipes_df.loc[recipes_df["name"].str.len().idxmax(), "name"]

print(shortest_recipe)
print(longest_recipe)
# Out:
# bread
# baked tomatoes with a parmesan cheese crust and balsamic drizzle

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 2.2 More EDA
# rubric={points:2}
#
# **Your tasks:**
# 1. Create a word cloud for the recipe names. You can use [the `wordcloud` package](https://github.com/amueller/word_cloud) for this, which you will have to install in the course environment.
# ```
# > conda activate cpsc330
# > conda install -c conda-forge wordcloud
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.2
#
# </div>
#
# _Points:_ 2

# %%
text = " ".join(recipes_df["name"])

wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color="white",
    stopwords=set(STOPWORDS) | {"s", "S"},
).generate(text)

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 2.3 Representing recipe names
# rubric={points:3}
#
# The next step is creating a representation of recipe names.
#
# **Your tasks:**
#
# 1. Similar to Exercise 1, create sentence embedding representation of recipe names (`name` column in `recipes_df`).  For the rest of the homework, we'll stick to the sentence embedding representation of recipe names.
#
#
# > You might have to convert the recipe names to a list (`recipes_df["name"].tolist()`) for the embedder to work
# > *If you create a dataframe with sentence embedding representation, set the index to `recipes_df.index` so that the indices match with the indices of the sample we are working with.*
# > **This might take a while to run.**
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_2.3
#
# </div>
#
# _Points:_ 3

# %%
embeddings = pd.DataFrame(
    embedder.encode(recipes_df["name"].tolist()),
    index=recipes_df.index
)

embeddings
# Out:
#                0         1         2         3         4         5         6  \
# 42      0.019592 -0.088336  0.072677 -0.034575 -0.048741 -0.049801  0.175334
# 101    -0.000567 -0.011825  0.073199  0.058176  0.031688 -0.015428  0.168134
# 129    -0.022603  0.065034 -0.033065  0.014450 -0.105039 -0.050559  0.100076
# 138    -0.066915  0.025988 -0.087689 -0.006847 -0.012861  0.049035  0.035351
# 163    -0.007068 -0.007308 -0.026629 -0.004153 -0.052810  0.011126  0.024000
# ...          ...       ...       ...       ...       ...       ...       ...
# 231514 -0.052718  0.008980 -0.046014  0.030194  0.005201  0.009964 -0.006760
# 231539 -0.088941  0.000887 -0.033383 -0.005739 -0.004215 -0.051114  0.036421
# 231547 -0.080801  0.004295 -0.044325  0.038307 -0.030125 -0.063566  0.004788
# 231596 -0.060801  0.111672 -0.108755  0.052323 -0.099851 -0.027532  0.084190
# 231629 -0.085059  0.009065 -0.088442 -0.008907  0.002234 -0.055801  0.039431
#
#                7         8         9  ...       374       375       376  \
# 42     -0.055191  0.020301  0.019828  ...  0.063293 -0.067171  0.087500
# 101     0.000466  0.033078 -0.013923  ... -0.012926 -0.015949  0.031315
# 129     0.022929 -0.037398  0.011857  ...  0.007971 -0.019165  0.004935
# 138     0.124966 -0.011697 -0.050179  ... -0.042345 -0.005794 -0.031800
# 163    -0.036994  0.023526 -0.046870  ... -0.018432  0.051918  0.036101
# ...          ...       ...       ...  ...       ...       ...       ...
# 231514  0.030238 -0.031474  0.024632  ...  0.075467  0.000967  0.085033
# 231539  0.040441 -0.002044 -0.030125  ...  0.095984 -0.030486  0.075810
# 231547  0.004822  0.015525 -0.040094  ...  0.066642  0.016605  0.096211
# 231596 -0.004861  0.002891  0.013943  ...  0.038082 -0.014214  0.048392
# 231629 -0.037784  0.005315 -0.078361  ...  0.063838  0.035654  0.031519
#
#              377       378       379       380       381       382       383
# 42     -0.061550  0.039297 -0.050147  0.027708  0.056843  0.056152 -0.122506
# 101    -0.059074  0.014143 -0.047270  0.007844  0.035501  0.076061 -0.078119
# 129     0.009005  0.000919 -0.040078  0.008650 -0.075781 -0.083477 -0.123240
# 138     0.120664 -0.057335 -0.077068  0.001653 -0.048223  0.116455  0.021789
# 163    -0.035312  0.005817  0.101802 -0.063171 -0.007917  0.089744  0.006997
# ...          ...       ...       ...       ...       ...       ...       ...
# 231514 -0.006520  0.031094  0.072901 -0.094975 -0.052466 -0.003300 -0.006991
# 231539 -0.059993  0.053136  0.015467 -0.063768  0.012493  0.056672  0.016758
# 231547 -0.023969  0.045752  0.017091 -0.062939 -0.016950  0.012060  0.039776
# 231596  0.050377  0.015281  0.106766  0.032009  0.020113  0.004977 -0.005828
# 231629 -0.006411  0.007804  0.016261 -0.006218  0.016956  0.019806 -0.042820
#
# [9100 rows x 384 columns]

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Clustering recipe names
# <hr>
#
# In this exercise you'll cluster recipe names with some of the clustering algorithms we have seen in class. This will also involve making some attempts to pick reasonable hyperparameter values for each clustering method based on the quality of the resulting clusters. For example, for KMeans, you need to specify the number of clusters in advance, which is often challenging on real-world datasets. For DBSCAN, you need to pick appropriate `eps` and `min_samples`. For hierarchical clustering, you need to pick a suitable linkage criterion, distance metric, and prune the tree so that it's possible to visualize and interpret it.
#
# Here are some methods which may help you with picking reasonable values for the hyperparameters.
# - Visualize the Elbow plot (KMeans).
# - Visualize Silhouette plots.
# - Visualize resulting clusters using `plot_umap_clusters` function from Exercise 1.
# - Sample some recipes from each cluster, manually inspect whether there are coherent semantic themes. (For this, you may use the function `print_clusters` given below.)
#
# > You may use the [`yellowbrick`](https://www.scikit-yb.org/en/latest/) package for visualizing the Elbow plot and the Silhouette plots. You can intall it with
#
# ```conda install -c districtdatalabs yellowbrick```
#
# **Note that the process of picking reasonable hyperparameter values will be exploratory, iterative, and will involve manual inspection and judgment, as there is no ground truth to verify how well the model is doing. In your solutions, please do not include everything you try. Only present the results of the most informative trials. Add a narrative to your answer so that it's easy for the grader to follow your choices and reasoning.**

# %%
def print_clusters(recipes_df, cluster_labels, n_recipes=10, replace=False, random_state=None):
    """
    Given recipes_df containing recipe names and cluster assignment (labels), 
    sample and print n_recipes recipes per cluster. 

    Parameters
    -----------
    recipe_df : pandas dataframe 
        recipes dataframe containing recipe names in the "name" column
    cluster_labels : ndarray or a list
        cluster labels for each row in recipes_df 
    n_recipes : int
        number of examples to sample from each cluster
    replace: bool
        replace flag to pass to the sampling of recipe names

    Returns
    -----------
    None
    """    
    
    grouped = (
        pd.DataFrame(
            {
                "name": recipes_df["name"],
                "cluster_label": cluster_labels,
            }
        )
        .sort_values("cluster_label")
        .groupby("cluster_label")    
    )
    
    for name, group in grouped:
        print(f"Cluster {name}")        
        print(("----------").format(""))        
        print("\n".join(group.sample(n_recipes, random_state=random_state, replace=replace)['name'].tolist()))
        print("\n\n")

# %% [markdown]
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 3.1 K-Means
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Cluster recipe titles using KMeans. Make some attempts to determine the optimal number of clusters.
# 2. Pick one or two best models and justify your choice.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.1
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# I evaluated k = 3, 5, 8, and 11 using their inertia, silhouette scores, cluster size distribution, and qualitative recipe groupings. While the distortion score plot suggested an elbow at k = 8, its silhouette score dipped to 0.0442. The highest silhouette score occurred at k = 3 (0.0518), but k = 11 performed almost identically well (0.0516) while offering a significantly lower inertia (5635.07 vs. 6314.46). Most importantly, examining the recipe names revealed that k = 11 produced highly interpretable, distinct culinary categories. Such as dedicated clusters for soups, salads, cookies, and cakes, which were lost at lower values of k. Because the cluster sizes for k = 11 remained reasonably balanced (ranging from 255 to 1424 recipes) without any extremely tiny groups, I select k = 11 as the optimal balance between quantitative performance and qualitative interpretability.

# %%
# Use embedding matrix for clustering
X = embeddings.values
k_range = range(2, 21)
inertias = []
silhouette_scores = []

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(X)
    inertias.append(km.inertia_)
    silhouette_scores.append(silhouette_score(X, labels))

# %%
# Elbow Plot
kelbow_inertia = KElbowVisualizer(KMeans(random_state=42), k=(2, 21), force_model=True)
kelbow_inertia.fit(X)
kelbow_inertia.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Silhouette Plot
kelbow_silhouette = KElbowVisualizer(
    KMeans(random_state=42), k=(2, 21), metric="silhouette", force_model=True
)
kelbow_silhouette.fit(X)
kelbow_silhouette.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
# Compare different k values
candidate_ks = [3, 5, 8, 11]

rows = []

for k in candidate_ks:
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(X)
    
    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique, counts))
    
    rows.append({
        "k": k,
        "inertia": km.inertia_,
        "silhouette": silhouette_score(X, labels),
        "min_cluster_size": counts.min(),
        "max_cluster_size": counts.max(),
        "cluster_sizes": cluster_sizes
    })

results_df = pd.DataFrame(rows).sort_values("silhouette", ascending=False).reset_index(drop=True)
results_df
# Out:
#     k      inertia  silhouette  min_cluster_size  max_cluster_size  \
# 0  3   6314.463867  0.051823    2095              3511
# 1  11  5635.073242  0.051554    255               1424
# 2  8   5792.992188  0.044245    573               2209
# 3  5   6150.671387  0.035758    840               3038
#
#                                                                                  cluster_sizes
# 0  {0: 3511, 1: 3494, 2: 2095}
# 1  {0: 956, 1: 1114, 2: 719, 3: 863, 4: 963, 5: 810, 6: 569, 7: 667, 8: 760, 9: 1424, 10: 255}
# 2  {0: 1447, 1: 1106, 2: 2209, 3: 928, 4: 1207, 5: 812, 6: 573, 7: 818}
# 3  {0: 1388, 1: 1798, 2: 840, 3: 3038, 4: 2036}

# %%
# Inspect recipe names inside each cluster
for k in candidate_ks:
    print(f"k = {k}")
    
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(X)
    
    temp_df = recipes_df.copy()
    temp_df["cluster"] = labels
    
    print("Silhouette score:", silhouette_score(X, labels))
    print("Cluster sizes:")
    print(temp_df["cluster"].value_counts().sort_index())
    
    print_clusters(recipes_df, labels, n_recipes=10, random_state=42)
# Out:
# k = 3
# Silhouette score: 0.05182264372706413
# Cluster sizes:
# cluster
# 0    3511
# 1    3494
# 2    2095
# Name: count, dtype: int64
# Cluster 0
# ----------
# bacon and egg breakfast stromboli
# potato vegetable quilt
# classic tomato soup cake
# quick braised broccoli with sun dried tomatoes and goat cheese
# dad s day burgers
# bibb lettuce salad with blueberry vinaigrette
# bikini ready  light creamy parmesan dressing
# french onion sandwiches
# creamed spinach with honey glazed pine nuts
# christina s decadent spinach salad
#
#
#
# Cluster 1
# ----------
# best ever chocolate zucchini cake
# really good chocolate mint parfait bars
# chocolate chip meringue bars
# mini chocolate chip crumb cake
# penzeys banana bread
# dreamsicle creamsicle on the rocks
# rosemary lemon cake
# creamy peach pie
# ultimate raisin slice
# riverdale diner cake
#
#
#
# Cluster 2
# ----------
# prize winning festive phyllo tarts
# baklava syrup
# limey apricot rum cooler
# mexicchini lasagna
# rita s polenta lasagna
# blueberry streusel scones
# lychee saketini blush
# easy babaganoush 1 2 3
# chive spatzel
# oak alley s sweet mint iced tea
#
#
#
# k = 5
# Silhouette score: 0.035757776349782944
# Cluster sizes:
# cluster
# 0    1388
# 1    1798
# 2    840
# 3    3038
# 4    2036
# Name: count, dtype: int64
# Cluster 0
# ----------
# foghorn
# dijon cheesesteak hoagies
# maine blueberry gateau
# samosa
# treasure chest bars
# lima bean cassoulet
# mrs  delnegro s shrimp mold
# tequichi
# turtle dove latte
# spaghetti squares
#
#
#
# Cluster 1
# ----------
# backwards chocolate cookies
# old fashioned sour cream sugar cookies
# hershey s classic chocolate chip cookies
# brenda s carrot cake
# fig cookies
# smucker s banana cookies with peanut butter filling
# chocolate luxury
# magic carpet cookies
# cranberry crumble coffee cake
# rocky road cookie sandwiches
#
#
#
# Cluster 2
# ----------
# white chocolate martini   pete evans
# alabammy delight
# easy strawberries   cream hot tea
# pink sauterne cocktail
# liquid cocaine
# clear lollypops and drops
# peppermint snaps
# my own spicy sweet noodle kugel
# gino s marvelous mojitos
# blood orange margarita
#
#
#
# Cluster 3
# ----------
# never fail scalloped potatoes
# pesto and potato tart
# stove top margarita chicken with fresh corn relish
# pesto chicken roll ups
# red cabbage with apple and bacon
# green eggs  noodles  and ham
# crispy chicken with peanut dipping sauce
# tater tot  beef   cheese casserole
# split pea soup  my way
# smooshed potatoes
#
#
#
# Cluster 4
# ----------
# peanut butter streusel  for brownies
# pumpkin spice crescent breakfast rolls
# marble swirl brownie cupcakes
# light italian zucchini crescent pie
# butter crescent rolls
# banana walnut and date loaf
# butter tart slice
# coconut banana cream pie  raw vegan
# egyptian eggplant dish  masaa a
# chocolate coconut crispies
#
#
#
# k = 8
# Silhouette score: 0.04424455761909485
# Cluster sizes:
# cluster
# 0    1447
# 1    1106
# 2    2209
# 3    928
# 4    1207
# 5    812
# 6    573
# 7    818
# Name: count, dtype: int64
# Cluster 0
# ----------
# golden dream
# dry martini
# raspberry colada
# dublin coddle   ireland
# nuclear ice tea
# dan street special
# aquavit cranberry breeze
# zesty bloody mary
# rose water face mask
# white lady  no egg
#
#
#
# Cluster 1
# ----------
# gingerbread men from a cake mix
# outrageous carrot cake
# honeybee gluten free dump cake
# chocolate pistachio cake
# lemon dream cake
# duncan hines almond pound cake
# creamy nutella cheesecake
# cake mix peanut butter bars
# grated cheesecake
# matzo cake
#
#
#
# Cluster 2
# ----------
# chipotle ranch  popcorn
# pork tenderloin in pan sauce
# cheese and spinach stuffed portobellos
# sole almondine with shrimp
# herbed cheese stuffed salmon
# harvest pumpkin soup
# whiskey glazed t bone steak
# nif s yummy basic meatballs
# avocado chimichurri bruschetta
# beef noodle company casserole
#
#
#
# Cluster 3
# ----------
# cinnamon banana bread
# whole grain honeyed waffles
# peanut butter cinnamon toast
# cherry buttermilk clafoutis
# pinto quick bread with dates
# cheesy herbed garlic bread
# blueberry protein muffins or cookies
# gingerbread cupcakes
# going bananas for banana bread
# good morning muffins
#
#
#
# Cluster 4
# ----------
# modern morocco coffee cinnamon ice cream
# orange berry swirl
# golden coconut crisps
# chocolate covered caramel peanut bars
# king arthur flour s best fudge brownies
# diet soda floats
# simple chocolate chess pie
# yukon gold and sweet potato gratin
# lemony brown sugar baked rice pudding
# hazelnut chewies
#
#
#
# Cluster 5
# ----------
# honey roasted peanut cookies
# cookies  n creme brownies
# cherry butter cookies
# double chocolate cookies   mint chocolate variation
# wholesome cookies
# mrs  field s soft and chewy peanut butter cookies
# cardamom cookies recipe   india
# chocolate chip cookies with oatmeal  flax  cranberries  and nuts
# joy of cooking s oatmeal cookies
# chocolate chip molasses cookies
#
#
#
# Cluster 6
# ----------
# egg salad with bacon and olives
# connie griffin s  signature salad
# creamy balsamic salad dressing
# gouda spinach salad
# cilantro caesar salad
# blue cheese chicken salad sandwiches
# light and creamy fruit salad
# chef salad  dressing
# annie s spinach salad
# homemade  suddenly salad
#
#
#
# Cluster 7
# ----------
# emilie s favorite chicken and rice
# barbecued chicken hash
# moroccan peach roasted chicken
# baked citrus chicken with basil cream sauce
# southern fried barbecue chicken
# chicken with bacon
# asian sticky chicken
# spicy marmalade glazed chicken
# chicken breast with chili cheese
# chicken with an asian flair
#
#
#
# k = 11
# Silhouette score: 0.051554013043642044
# Cluster sizes:
# cluster
# 0     956
# 1     1114
# 2     719
# 3     863
# 4     963
# 5     810
# 6     569
# 7     667
# 8     760
# 9     1424
# 10    255
# Name: count, dtype: int64
# Cluster 0
# ----------
# lemon jumbles
# skip and go barefoot
# mob witnesses
# natale stuffed portobellos
# pine berry crush
# hilary wallbanger
# jalapeno boats
# alsatian rub
# afterburner  3
# kelly s  chunky  haystacks
#
#
#
# Cluster 1
# ----------
# perfect german butter cake
# sour cream chocolate fudge cake with chocolate buttercream
# ginger chai glazed bundt cake
# beatty s chocolate cake  barefoot contessa
# scotch chocolate cake
# banana cheesecake hotel borobudur jakarta
# sweet potato pound cake
# traditional butter cake
# grand marnier poppy seed cake
# chocolate fluffer nutter cake
#
#
#
# Cluster 2
# ----------
# sweet   sour chicken pita burgers
# pork chops in tomato sage sauce
# swiss   beef crescent ring
# ground beef wellingon
# bbq ribs with sauce
# grilled mexiburgers
# emeril s breaded   baked pork chops
# sausage   peppers  slow cooked
# peanut butter cup sandwich
# low carb  keto  shrimp and sausage gumbo
#
#
#
# Cluster 3
# ----------
# yellow squash muffins
# rich egg bread
# cream cheese and chocolate muffin cakes
# baked french swirl toast
# over the top zucchini bread
# southern style baked beans
# fluffy banana graham pancakes
# nana s poppy seed bread
# cheesy italian batter breadsticks
# blueberry cream cheese french toast
#
#
#
# Cluster 4
# ----------
# oatmeal raisin protein bars
# chocolate   coffee   cream
# white chocolate boysenberry cappuccino
# peanut butter banana chocolate train wreck
# nearly no fat fudge brownies
# espresso brownies
# banana cream protein pie
# cheesecake lemon bars
# butterscotch almond bars
# sweet nuts and bolts
#
#
#
# Cluster 5
# ----------
# irish butter cookies
# banana chocolate chip oatmeal cookies
# chocolate cookies w hershey s cocoa powder
# pumpkin oatmeal cookies
# brittany s favorite cookies
# yummy oatmeal raisin cookies
# big soft and chewy chocolate chip cookies
# socks off oatmeal cookies  no raisins
# cherry winks cookies
# marshmallow fudge cookies
#
#
#
# Cluster 6
# ----------
# italian salad dressing
# mom s coleslaw dressing
# grandma weseman s english pea salad
# diva salad
# broccoli delight salad
# ginger peanut chicken salad wrapsyou
# creamy salad
# mixed green salad and mustard vinaigrette
# bikini ready  light creamy parmesan dressing
# laura s family secret creamy italian dressing
#
#
#
# Cluster 7
# ----------
# buffett blueberry blaster margarita
# french vanilla mocha coffee mix
# coffee body scrub
# herbed vinaigrette
# coffee alla chocolata
# cactus margarita
# butterscotch truffle martini
# pineapple champagne cosmopolitan
# vodka caramel apple cider
# afternoon coffee
#
#
#
# Cluster 8
# ----------
# french roast chicken
# karen s chicken and white sauce
# chicken in basil cream
# rosemary chicken breasts
# spicy moroccan chicken skewers
# cuban style braised chicken
# weight watchers chicken parmesan
# cilantro pesto chicken tenders
# thai bbq chicken wings
# creamy chicken enchiladas
#
#
#
# Cluster 9
# ----------
# kicked up bacon cheese mashed potatoes
# olive marinate
# herbed cream cheese appetizers
# creamy rice casserole
# mariscada en salsa verde   seafood stew in green sauce
# peppercorn crusted salmon with white wine butter sauce
# baby frise with poached egg and pancetta
# sweet pink popcorn
# skinny bride s guide to ham and potato casserole
# broiled sirloins
#
#
#
# Cluster 10
# ----------
# chicken and potato florentine soup  olive garden
# immunity building miso soup
# creamy chicken taco soup
# quinoa corn soup
# collard green   black eyed pea soup
# potato  leek  and roasted garlic soup
# spicy black bean and rice soup
# chicken noodle souperole
# fat free veggie soup to die for
# kale  sweet potato and white bean soup

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 3.2 DBSCAN
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Cluster recipe names using `DBSCAN` with `metric="cosine"`. Make some attempts to tune the  hyperparameters `eps` and `min_samples`.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.2
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# I explored DBSCAN with different eps and min_sample_values, but it struggled to find meaningful groupings. Instead of creating balanced categories, it lumped almost everything into one massive cluster, which is a common issue when clustering complex text data.

# %%
# Explore different DBSCAN hyperparameters
eps_values = [0.35, 0.38, 0.40, 0.42, 0.45, 0.50]
min_samples_values = [5, 6, 8, 10]

rows = []

for eps in eps_values:
    for min_samples in min_samples_values:
        db = DBSCAN(eps=eps, min_samples=min_samples, metric="cosine")
        labels = db.fit_predict(X)

        # Noise points have label -1
        n_noise = np.sum(labels == -1)
        noise_frac = n_noise / len(labels)

        # Non-noise labels
        core_mask = labels != -1
        unique_clusters = sorted([c for c in np.unique(labels) if c != -1])
        n_clusters = len(unique_clusters)

        # Silhouette on non-noise points only (if there is >1 cluster)
        if n_clusters > 1 and core_mask.sum() > n_clusters:
            sil = silhouette_score(X[core_mask], labels[core_mask], metric="cosine")
        else:
            sil = np.nan

        # Cluster sizes
        if n_clusters > 0:
            cluster_sizes = pd.Series(labels[core_mask]).value_counts().sort_index()
            min_size = cluster_sizes.min()
            max_size = cluster_sizes.max()
        else:
            min_size = np.nan
            max_size = np.nan

        rows.append(
            {
                "eps": eps,
                "min_samples": min_samples,
                "n_clusters": n_clusters,
                "noise_frac": noise_frac,
                "silhouette": sil,
                "min_cluster_size": min_size,
                "max_cluster_size": max_size,
            }
        )

results_dbscan = pd.DataFrame(rows).sort_values(
    ["silhouette", "noise_frac"], ascending=[False, True]
).reset_index(drop=True)

results_dbscan
# Out:
#      eps  min_samples  n_clusters  noise_frac  silhouette  min_cluster_size  \
# 0   0.42  8            2           0.084835    0.161812    7
# 1   0.38  8            2           0.154286    0.132552    5
# 2   0.42  6            3           0.075934    0.089579    6
# 3   0.40  6            4           0.105165    0.089415    6
# 4   0.40  5            4           0.099231    0.088959    5
# 5   0.42  5            4           0.071758    0.084344    5
# 6   0.35  8            2           0.254396    0.081285    8
# 7   0.40  8            2           0.115275    0.015977    2
# 8   0.38  5            6           0.132418    0.009453    3
# 9   0.38  6            3           0.141538    0.004002    3
# 10  0.35  10           4           0.276593   -0.037902    8
# 11  0.35  5            9           0.215495   -0.042901    2
# 12  0.35  6            7           0.225824   -0.050348    5
# 13  0.50  5            1           0.021978   NaN          8900
# 14  0.50  6            1           0.022967   NaN          8891
# 15  0.50  8            1           0.025165   NaN          8871
# 16  0.50  10           1           0.026813   NaN          8856
# 17  0.45  5            1           0.046593   NaN          8676
# 18  0.45  6            1           0.048791   NaN          8656
# 19  0.45  8            1           0.053516   NaN          8613
# 20  0.45  10           1           0.057033   NaN          8581
# 21  0.42  10           1           0.088462   NaN          8295
# 22  0.40  10           1           0.122637   NaN          7984
# 23  0.38  10           1           0.167033   NaN          7580
#
#     max_cluster_size
# 0   8321
# 1   7691
# 2   8397
# 3   8125
# 4   8180
# 5   8430
# 6   6777
# 7   8049
# 8   7870
# 9   7803
# 10  6548
# 11  7095
# 12  7007
# 13  8900
# 14  8891
# 15  8871
# 16  8856
# 17  8676
# 18  8656
# 19  8613
# 20  8581
# 21  8295
# 22  7984
# 23  7580

# %%
# Inspect recipe names inside DBSCAN configurations
candidate_settings = [
    (0.35, 5),
    (0.40, 5),
    (0.45, 5),
    (0.40, 8),
]

for eps, min_samples in candidate_settings:
    print(f"eps = {eps}, min_samples = {min_samples}")
    
    db = DBSCAN(eps=eps, min_samples=min_samples, metric="cosine")
    labels = db.fit_predict(X)

    temp_df = recipes_df.copy()
    temp_df["cluster"] = labels

    non_noise = labels != -1
    n_clusters = len(set(labels[non_noise]))
    noise_frac = (labels == -1).mean()
    
    # Compute silhouette only on non-noise clusters when meaningful
    if n_clusters > 1 and non_noise.sum() > n_clusters:
        sil = silhouette_score(X[non_noise], labels[non_noise], metric="cosine")
    else:
        sil = float("nan")

    print("Silhouette score (non-noise):", sil)
    print("Noise fraction:", noise_frac)
    print("Cluster sizes:")
    print(temp_df["cluster"].value_counts().sort_index())

    print_clusters(
        recipes_df[non_noise],
        labels[non_noise],
        n_recipes=10,
        replace=True,
        random_state=42,
    )
# Out:
# eps = 0.35, min_samples = 5
# Silhouette score (non-noise): -0.042901333421468735
# Noise fraction: 0.2154945054945055
# Cluster sizes:
# cluster
# -1    1961
#  0    7095
#  1    8
#  2    7
#  3    6
#  4    7
#  5    5
#  6    5
#  7    4
#  8    2
# Name: count, dtype: int64
# Cluster 0
# ----------
# bread pudding with warm bourbon sauce
# quinoa with oyster mushrooms and adzuki beans
# potato gratin with porcini mushrooms and mascarpone cheese
# pork chops madrid
# lemon butter cake
# green curry chicken n veg kebabs over rice
# saucy honey dijon chicken
# strawberry milkshake
# banana bread with walnuts and orange zest
# pure maple brownies
#
#
#
# Cluster 1
# ----------
# tre s famous bloody mary
# uncle wayne s bloody mary
# shandong mary cocktail
# tre s famous bloody mary
# bloody mary cocktail
# old bay bloody mary
# shandong mary cocktail
# shandong mary cocktail
# tre s famous bloody mary
# beau rivage bloody mary mix
#
#
#
# Cluster 2
# ----------
# silver dragon
# bronze dragon
# flaming green dragon
# silver dragon
# flaming angry dragon
# flaming green dragon
# flaming green dragon
# silver dragon
# black unicorn
# flaming angry dragon
#
#
#
# Cluster 3
# ----------
# golden kiss
# raspberry kiss
# vicious kiss
# raspberry kiss
# raspberry kiss
# silky kiss
# vicious kiss
# vicious kiss
# vicious kiss
# raspberry kiss
#
#
#
# Cluster 4
# ----------
# pork medallions with wine and sage
# pork medallions in wine sauce
# pork medallions with chanterelles
# pork medallions with wine and sage
# pork medallions in apple mustard sauce
# pork medallions with chanterelles
# pork medallions with chanterelles
# pork medallions with wine and sage
# pork tenderloin medallions with fresh figs
# pork medallions in apple mustard sauce
#
#
#
# Cluster 5
# ----------
# midori sex on the beach
# creamy sex on the beach
# tgi friday s sex on the beach
# creamy sex on the beach
# creamy sex on the beach
# frozen sex on the beach
# tgi friday s sex on the beach
# tgi friday s sex on the beach
# tgi friday s sex on the beach
# creamy sex on the beach
#
#
#
# Cluster 6
# ----------
# lolly s almond torte
# pistachio fudge torte
# kato s  chocolate hazelnut delight  torte
# pistachio fudge torte
# pistachio fudge torte
# fudgy chocolate torte
# kato s  chocolate hazelnut delight  torte
# kato s  chocolate hazelnut delight  torte
# kato s  chocolate hazelnut delight  torte
# pistachio fudge torte
#
#
#
# Cluster 7
# ----------
# mr coffee mocha frappe
# chocolate mocha frappe
# baileys mocha frapp
# mr coffee mocha frappe
# mr coffee mocha frappe
# chocolate mocha frappe
# baileys mocha frapp
# baileys mocha frapp
# mr coffee mocha frappe
# hg s mocha happy frappe
#
#
#
# Cluster 8
# ----------
# the best pumpkin squares
# pumpkin gooey chess squares
# the best pumpkin squares
# the best pumpkin squares
# the best pumpkin squares
# pumpkin gooey chess squares
# the best pumpkin squares
# the best pumpkin squares
# the best pumpkin squares
# pumpkin gooey chess squares
#
#
#
# eps = 0.4, min_samples = 5
# Silhouette score (non-noise): 0.08895887434482574
# Noise fraction: 0.09923076923076923
# Cluster sizes:
# cluster
# -1    903
#  0    8180
#  1    6
#  2    6
#  3    5
# Name: count, dtype: int64
# Cluster 0
# ----------
# super chewy chocolate chip cookies
# tom yam siam cocktail
# blackberry jam cupcakes
# openfaced mushroom sandwich
# no fuss chicken
# new years fruity smoothie
# high protein diet  cornell  bread
# fluffy rice and chicken
# pepper lime chicken
# red scalloped potatoes
#
#
#
# Cluster 1
# ----------
# queeny tini
# real bellini s
# hpno tini
# real bellini s
# real bellini s
# frozen bellini
# hpno tini
# hpno tini
# hpno tini
# real bellini s
#
#
#
# Cluster 2
# ----------
# tgi friday s sex on the beach
# sex on the moon
# sex on the grass
# sex on the moon
# sex on the moon
# frozen sex on the beach
# sex on the grass
# sex on the grass
# sex on the grass
# sex on the moon
#
#
#
# Cluster 3
# ----------
# pollo asado
# saltimbocca alla pollo
# pollo frito
# saltimbocca alla pollo
# saltimbocca alla pollo
# pollo alla cacciatora
# pollo frito
# pollo frito
# pollo frito
# saltimbocca alla pollo
#
#
#
# eps = 0.45, min_samples = 5
# Silhouette score (non-noise): nan
# Noise fraction: 0.04659340659340659
# Cluster sizes:
# cluster
# -1    424
#  0    8676
# Name: count, dtype: int64
# Cluster 0
# ----------
# sourdough sandwich buns  schlotzsky style
# biscuit balls
# my favorite chocolate chip cake
# miss kitty s chili con carne
# orange glazed cranberry crowns
# pork medallions in wine sauce
# bacon cornbread
# killer chocolate  brownie cake  original author david beale
# oatmeal chocolate chip lactation cookies by noel trujillo
# veggie blend stuffed breasts
#
#
#
# eps = 0.4, min_samples = 8
# Silhouette score (non-noise): 0.015976756811141968
# Noise fraction: 0.11527472527472528
# Cluster sizes:
# cluster
# -1    1049
#  0    8049
#  1    2
# Name: count, dtype: int64
# Cluster 0
# ----------
# tahina dressing   sauce
# turtle cheesecake  reduced fat
# blondies with variations
# oven baked parmesan romano chicken
# oatmeal raisin bran cookies
# oat flour pumpkin bread
# 1 lb abm hawaiian sweet bread
# fresh fruit pizza  paula deen
# pink  lemonade spritzer
# roasted cauliflower with capers
#
#
#
# Cluster 1
# ----------
# eggplant crispy and delicious
# honey roasted eggplant with chiles
# eggplant crispy and delicious
# eggplant crispy and delicious
# eggplant crispy and delicious
# honey roasted eggplant with chiles
# eggplant crispy and delicious
# eggplant crispy and delicious
# eggplant crispy and delicious
# honey roasted eggplant with chiles

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 3.3 Hierarchical clustering
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Try hierarchical clustering with `metric="cosine"` on this problem. Show a dendrogram by using a suitable truncation method.
# 2. Create flat clusters by cutting the tree at the appropriate level.
#
# > *Note: Try orientation="left" of `dendrogram` for better readability of the dendrogram.*
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.3
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# I applied hierarchical clustering with complete linkage and cosine distance, and examined flat clusterings at k = 5 and k = 11. In both cases, the resulting clusters were fairly uneven and several groups contained a mix of unrelated recipe types rather than a single clear theme. For example, some clusters combined beverages, desserts, and main dishes, which made them harder to interpret than the K-Means clusters. Overall, hierarchical clustering captured some local similarities, but it did not produce clusters that were as clean or as semantically coherent as the K-Means solution for this dataset.

# %%
# Hierarchical clustering with cosine metric
Z = linkage(X, method="complete", metric="cosine")

# Dendrogram
plt.figure(figsize=(10, 8))
dendrogram(
    Z,
    orientation="left",
    truncate_mode="lastp",
    p=20,
    show_leaf_counts=True,
    leaf_font_size=10,
)
plt.xlabel("Distance (cosine)")
plt.title("Hierarchical clustering")
plt.tight_layout()
plt.show()

# %%
# Cut the tree to get flat clusters
n_clusters = 11
hier_labels = fcluster(Z, t=n_clusters, criterion="maxclust")

# Make labels 0-based
hier_labels = hier_labels - 1

print_clusters(recipes_df,
               hier_labels,
               n_recipes=20,
               random_state=42)
# Out:
# Cluster 0
# ----------
# oven baked mostaccioli
# chicken and cashews
# spinach pizza crust
# sauteed chicken breast with clover honey and chili
# stuffed chicken breast in a white wine cream sauce
# johnny jalapeno s ride em cowboy corncakes
# pan fried moroccan chicken
# lasagna  classic mueller s recipe
# grilled chicken on julienned vegetables with butternut chips
# grand marnier marinated chicken
# bistro style mustard vinaigrette
# brown sugar vinaigrette
# spinach and ricotta ravioli
# cheesy spinach bake
# addictive green enchiladas
# donair meat and donair sauce
# peppercorn crusted salmon with white wine butter sauce
# pacific rim salmon fettuccine
# bacon and cheese stuffed chicken breasts
# tasty turkey meatloaf
#
#
#
# Cluster 1
# ----------
# baked caprese salad
# smoky waldorf salad
# green spring salad
# emeril lagasse s moroccan mint tea
# lime ginger syrup for fruit salads  weight watchers
# rogene s  italian vegetable soup
# waldorf salad on the lighter side
# nif s baked pasta with shrimp and chicken
# tunisian salad
# twice baked sweet potatoes   on the light side
# strawberry salad
# rosemary parmesan coins
# roasted garlic pasta toss
# citrus and pomegranate beef salad
# potato  tomato and cilantro salad
# sweet sesame salad
# spanish rice and meatballs
# slow cooker north woods wild rice soup
# fast and easy bean and corn salad
# fat box
#
#
#
# Cluster 2
# ----------
# after 8 shooter
# treasure chest bars
# monte cristo  cocktail
# hg s mega monsterburger   ww points   6
# mr  funk s punch
# the best pumpkin squares
# maple nut filled dates
# t g i  friday nutty accountant
# rich  rich  rich   vanilla and  fig squares
# the blue lagoon
# red beans   sausage jambalaya
# turmeric broth for sipping
# pina colada cookies
# 8th birthday
# bananas foster cheesecake squares
# are you crazy    alcoholic drink
# wrecked golf cart
# bran squares
# frozen vanilla honey bee
# holiday isle rum runner
#
#
#
# Cluster 3
# ----------
# sweet mincemeat cake
# pumpkin oatmeal cookies
# black forest crinkle cookies
# toll house cookies  ca  1968
# canadian butter tarts
# milk bread  bread machine
# chocolate layer dessert
# yellow squash muffins
# easy white bread
# oatmeal bannock  low fat
# banana walnut cake
# variety oatmeal cookie
# eggnog  sparkle  cookies
# maple syrup layer cake
# coffee jelly roll supreme
# dinette cake
# white chocolate chip cranberry cookies
# philadelphia oreo cheesecake
# cheesecake toffee drops
# blueberry lemon tea bread
#
#
#
# Cluster 4
# ----------
# the undercurrent
# baby elephant walk
# purple crayon
# pink fetish
# texas roadhouse cowboy quencher
# chanel no  6
# red  white and blue shooter
# sex on the grass
# bronze dragon
# piece of heaven shot
# hana passion
# hot cranberry toddy
# wakey wakey
# all american club
# bama breeze
# poor girl s stroganoff
# ding dong dessert
# caribbean cassis
# matcha  green tea  pound cake
# mock filet mignon
#
#
#
# Cluster 5
# ----------
# absolut trouble
# tasty tamale pie   casserole
# sunset passion colada
# sweating colombian
# pasteles de yuca
# vellini
# cindy s stromboli
# vanita s insalata verde
# rude cosmopolitan
# melanie s moussaka
# straight caesar
# philippine lumpias
# antonio s house italian
# french canadian tourtire
# le petit marseillais
# pastel de tres leches
# nian gao
# enchiladas de pollo   paula deen
# cosmalize
# cape biryani breyani
#
#
#
# Cluster 6
# ----------
# crepe batter a la julia child
# 5 cup ambrosia
# a day at the beach
# skip and go barefoot
# beet  chickpea and almond dip
# tangy chip dip
# mincemeat hermits
# parmesan white bean dip
# tzatziki  barefoot contessa  ina garten
# avocado and tahini dip
# chopin s player s cup
# peanutty noodles  cooking light
# mexican corn dip
# sand drops
# food processor shrimp dip
# southern corn dip not mex
# floating on a cloud
# easy layer dip
# best ever croutons
# banana bran scones  cooking light
#
#
#
# Cluster 7
# ----------
# yummy mushroom parmesan
# sauerkraut rye bread  sugar free
# beef and bean chimichangas
# herbed focaccia bread
# sonora chicken strudel
# mushroom pasta pilaf
# afghan meat filled pasta  mantou
# no cream wild mushroom pasta sauce
# sorta zagna
# ooh la la aloha loaf
# crustless spainch and mushroom quiche
# hashweh   rice stuffing   middle east  palestine
# parma  chicken   mushroom cream pasta
# clams in a spicy broth
# new orleans dirty rice
# baby bok choy with sherry and prosciutto
# mushroom palmiers
# creamy morel mushroom sauce
# swiss steak bh g year 1937
# barb s sauteed swiss chard
#
#
#
# Cluster 8
# ----------
# black jack cocktails or black jacks
# chef boy i be illinois  warm white bean salad with prosciutto
# belafonte bars
# storming pink bourbon
# zen bars
# french chambord martini
# fudgy s more bars
# sirloin steak with dijon port sauce
# pamplemousse cocktail
# dry rub for pork
# pork honey oriental
# mexican iceberg  cocktail
# ally s low cal margarita
# blackberry tequila sunrise
# peach martini
# tony roma s chocolate martini
# ham delights
# tequila sunset
# pink prozac  cocktail
# frosted almond bars
#
#
#
# Cluster 9
# ----------
# citrus cod
# tostada bake
# green chili stuffing
# bailey s creme brulee
# tofu tahini spread
# karen s molasses crinkles
# pierogie
# moo shu vegetables
# watermelon mojito
# blondies with variations
# cream cheese braids
# kiwi klimax
# meloncello
# essential boy bribes
# a unique and delicious braided bread
# coconut mojito
# pinky lady lemonade cocktail
# hpnotiq lemonade
# strawberry lemon slices
# vermouth  leek and tarragon pan sauce
#
#
#
# Cluster 10
# ----------
# reverse whoopie pies
# espresso brownies
# golden graham cookies
# apple amaretto strudel
# grandmas brownies  gooey chewy
# bethie s baked french toast
# crispy ginger cookies
# pecan crumb cake
# chocolate orgasm
# blueberry pineapple pina colada pie
# extreme kahlua chocolate mousse
# coconut pumpkin custard
# bedtime butterscotch
# amaretto shake
# cranberry walnut slaw
# food for the gods
# quick one bowl brownies
# white chocolate cocomacs
# makeover french silk pie
# fudge filled blondies

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br>

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class="alert alert-info">
#
# ### 3.4 Manual interpretation of clusters
# rubric={points:6}
#
# **Your tasks:**
#
# 1. Label the topics/themes you see in the clusters created by different clustering methods.
# 2. Do you see a common theme across clusters created by different clustering methods? Do you see any differences between the clusters created by different clustering methods?
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_3.4
#
# </div>
#
# _Points:_ 6

# %% [markdown]
# ### Labeling the Topics/Themes
#
# **K-Means ($k=11$)**
# K-Means produced the most interpretable clusters overall, although not every cluster was perfectly pure. Several groups showed clear themes:
#
# * **Cluster 1:** Cakes
# * **Cluster 2:** Meat mains
# * **Cluster 3:** Breads, muffins, and breakfast-style baked foods
# * **Cluster 4:** Bars, brownies, and sweet dessert items
# * **Cluster 5:** Cookies
# * **Cluster 6:** Salads and dressings
# * **Cluster 7:** Coffee drinks, cocktails, and other beverages
# * **Cluster 8:** Chicken dishes
# * **Cluster 10:** Soups
#
# Other clusters, **Cluster 0** and **Cluster 9**, were more mixed and contained a combination of different recipe types, so they were harder to assign a single clean label.
#
# **DBSCAN**
# DBSCAN did not recover broad, well-separated categories. Instead, most recipes were assigned to one dominant cluster or left as noise, while a few very small clusters captured narrow local similarities. This suggests DBSCAN was more sensitive to dense local structure than to large, balanced thematic groupings.
#
# **Hierarchical clustering ($k=11$)**
# Hierarchical clustering produced several mixed clusters with weaker boundaries than K-Means. Some clusters had partial themes, but many combined unrelated recipe types such as drinks, desserts, dips, breads, and mains. Overall, the hierarchical solution was less coherent and less interpretable than the K-Means clustering.
#
# ### Common themes across methods
#
# The clearest recurring patterns were **beverages/cocktails** and **dessert or baked-good recipes**, since those titles tend to contain distinctive words. However, these themes appeared much more clearly in **K-Means** than in the other two methods.
#
# ### Differences between methods
#
# The main difference was interpretability. **K-Means** produced the cleanest and most semantically meaningful clusters, with recognizable groups such as soups, salads, cookies, cakes, and chicken dishes. **DBSCAN** tended to form one dominant cluster plus a few tiny clusters or noise points, so it did not give useful broad categories. **Hierarchical clustering** captured some local similarities, but many of its flat clusters were still too mixed to label confidently. For this dataset, K-Means was the most effective clustering method.

# %% [markdown]
# <!-- END QUESTION -->
#
# <br><br><br><br>

# %% [markdown]
# Before submitting your assignment, please make sure you have followed all the instructions in the Submission Instructions section at the top.
#
# Here is a quick checklist before submitting:
#
# - [ ] Restart kernel, clear outputs, and run all cells from top to bottom.
# - [ ] `.ipynb` file runs without errors and contains all outputs.
# - [ ] Only `.ipynb` and required output files are uploaded (no extra files).
# - [ ] Execution numbers start at **1** and are in order.
# - [ ] If `.ipynb` is too large and doesn't render on Gradescope, also upload a PDF/HTML version.
# - [ ] Reviewed the [CPSC 330 homework instructions](https://ubc-cs.github.io/cpsc330-2025W2/docs/homework-instructions).

# %% [markdown]
# ![](img/eva-well-done.png)
